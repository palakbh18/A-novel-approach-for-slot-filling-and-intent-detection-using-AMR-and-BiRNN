# %%
with open('singleLineAMR.txt.anonymized') as f1, open('sentences') as f2:
  with open('output.txt','a') as out: 

    pits = []
    for x, y in zip(f1, f2):
        x = x.strip()
        y = y.strip()
       # print(y)
    #    print(x)
        abc = "\"amr\":\"{0}\",\n\"sent\": \"{1}\"".format(x, y)
   #     print(abc)
        xyz = "{"+abc+"}"
        print(xyz)
       # m=json.loads(xyz)
        pits.append(xyz)
        out.write(xyz)
#print(pits)
    #    print("\"amr\":\"{0}\",\n\"sent\": \"{1}\"".format(x, y))
      #  print("{0}\t{1}".format(x, y))

'''  
[{"amr": "describe :arg0 ( person :name ( name :op1 ryan )  )  :arg1 person :arg2 genius",
"sent": "ryan 's description of himself : a genius .",
"id": "demo"}]
'''
# Out:
# {"amr":"add :arg1 ( and :op1 ( person :name ( name :op1 don )  :wiki - )  :op2 ( person :name ( name :op1 sherri )  )  )  :arg2 meditate :arg3 ( sound :arg1 ( playlist :mod nature )  )",
# "sent": "Add Don and Sherri to my Meditate to Sounds of Nature playlist"}
# {"amr":"put :arg1 ( organization :name ( name :op1 united :op2 abominations )  )  :time ( onto :op1 ( playlist :arg1-of groove :arg1-of rare )  )",
# "sent": "put United Abominations onto my rare groove playlist"}
# {"amr":"add :arg0 ( watanabe :mod ( misato :op1 ( playlist :mod ( thing :name ( name :op1 trapeo )  )  )  )  )  :arg1 tune",
# "sent": "add the tune by misato watanabe to the Trapeo playlist"}
# {"amr":"add :arg0 this :arg1 ( artist :mod this )  :arg2 playlist",
# "sent": "add this artist to my this is miguel bosé playlist"}
# {"amr":"acoustic :mod evening :mod-of ( playlist :beneficiary-of ( choir :op1-of ( and :arg0-of ( add :arg1 heresy )  )  )  )  :op1-of hotel",
# "sent": "add heresy and the hotel choir to the evening acoustic playlist"}
# {"amr":"please :arg1 ( add :arg1 ( thing :name ( name :op1 jency :op2 anthony )  )  :arg2 ( playlist :arg0-of ( be :arg1 ( person :domain this :name ( name :op1 mozart )  :wiki wolfgang_amadeus_mozart )  )  )  )",
# "sent": "Please add Jency Anthony to my playlist This Is Mozart"}
# {"amr":"add :arg1 ( album :arg0-of ( list :arg1 ( country :arg1-of ( dance :arg0 ( date-entity :year 2017 )  )  :name ( name :op1 música )  )  :arg2 ( person :name ( name :op1 la :op2 mejor )  )  )  )",
# "sent": "Add an album to my list La Mejor Música Dance 2017"}
# {"amr":"add :arg1 ( shame :poss you )  :arg2 ( master :mod ( playlist :consist-of metal )  )",
# "sent": "Add shame on you to my masters of metal playlist"}
# {"amr":"add :arg1 artist :arg2 ( organization :mod playlist :name ( name :op1 epic :op2 gaming )  )",
# "sent": "Add artist to playlist Epic Gaming"}
# {"amr":"add :arg1 ( organization :name ( name :op1 private :op2 collection )  )  :time ( onto :op1 ( playlist :mod ( organization :name ( name :op1 cena :op2 elegante )  )  )  )",
# "sent": "Add The Private Collection onto my Cena Elegante playlist"}
# {"amr":"put :arg1 ( track :arg0-of dance :mod another )  :arg2 electronica",
# "sent": "Put another track in my electronica & dance"}
# {"amr":"dishwash :arg2-of ( call :arg1 ( playlist :arg2-of ( add :arg1 ( album :mod this )  )  )  )",
# "sent": "add this album to the playlist called dishwashing"}
# {"amr":"add :arg0 ( person :name ( name :op1 chab )  )  :arg1 ( punk :mod classic )",
# "sent": "add Classic Punk by Chab"}
# {"amr":"add :arg1 ( song :mod ( indie :mod ( mcdonough :mod megon )  :mod-of ( playlist :mod-of artist )  )  )  :arg2 slacker",
# "sent": "add megon mcdonough indie songs for slackers to playlist artist"}
# {"amr":"add :arg0 ( we :arg0-of ( dance :arg1 playlist :arg2 ( company :name ( name :op1 northern :op2 rock )  :wiki northern_rock )  )  )  :arg1 ( shall :name name )",
# "sent": "Add the name Shall We Dance to playlist Rock"}
# {"amr":"add :arg1 ( person :name ( name :op1 lee :op2 seung :op3 gi )  )  :arg2 ( playlist :mod ( thing :name ( name :op1 baila :op2 reggaeton )  )  )",
# "sent": "add Lee Seung gi to my Baila Reggaeton playlist"}
# {"amr":"put :arg1 ( farian :mod frank )  :arg2 ( playlist :arg1-of deep :mod ( folk :mod indie )  :mod dark )",
# "sent": "put frank farian on my Deep Dark Indie Folk playlist"}
# {"amr":"include :arg1 hohenfriedberg :arg2 pop",
# "sent": "Include hohenfriedberger marsch to my Novedades Pop"}
# {"amr":"add :arg1 ( person :name ( name :op1 alexandra :op2 govere )  )  :arg2 ( playlist :mod ( urbano :mod anochec )  )",
# "sent": "add alexandra govere to my anochecer urbano playlist"}
# {"amr":"put :arg0 please :arg1 ( song :poss yajima )  :arg2 ( thing :name ( name :op1 operación :op2 bikini )  :op1-of onto )",
# "sent": "Please put maimi yajima 's song onto Operación Bikini"}
# {"amr":"add :arg0 ( chill :mod playlist )  :arg1 ( she :mod ( government-organization :name ( name :op1 fe )  :name name :wiki danish_defence_intelligence_service )  )",
# "sent": "For my playlist chill add the name Cater Fe She"}
# {"amr":"add :time ( meet :arg0 ice :time ( cream :arg2 ( be :arg0 ( person :name ( name :op1 alejandro :op2 fernández )  )  :arg1 ( playlist :mod this )  )  )  )",
# "sent": "add when ice met cream to This Is Alejandro Fernández playlist"}
# {"amr":"add :arg0 ( organization :domain-of ( playlist :mod puccini )  :name ( name :op1 banana :op2 republic )  :topic this )",
# "sent": "Add Banana Republic to my this is puccini playlist"}
# {"amr":"add :arg1 ( track :name ( playlist :arg1-of wed :mod ( classic :part-of lina' )  )  )",
# "sent": "add the Chamillionaire track to lina's wedding classics playlist"}
# {"amr":"put :arg1 ( tune :arg0 ( person :name ( name :op1 kan :op2 mikami )  )  :mod this )  :arg2 ( cyclone :arg1-of find :arg1-of fresh )",
# "sent": "put this Kan Mikami tune on fresh finds cyclone"}
# {"amr":"add :arg1 ( mogi :mod mike )  :time ( onto :op1 ( digger :arg1-of ( crate :location-of ( playlist :mod anonymous )  )  )  )",
# "sent": "add mike mogis onto my crate diggers anonymous playlist"}
# {"amr":"add :arg1 ( person :name ( name :op1 jon :op2 mclaughlin )  )  :arg3 ( country :mod forever )",
# "sent": "Add Jon McLaughlin to my forever country"}
# {"amr":"neo :arg0-of ( add :arg1 sheila )  :mod-of ( soul :location-of ( love :arg0 i :arg1 playlist )  )",
# "sent": "add sheila e to my i love my neo soul playlist"}
# {"amr":"possible :arg0 ( mozart :domain this :mod-of playlist )  :arg1 ( add :arg0 you :arg1 ( something :mod man )  )",
# "sent": "Can you add something from Method Man to my this is mozart playlist"}
# {"amr":"add :arg1 ( artist :arg0-of ( hype :arg2-of list )  )",
# "sent": "Add an artist to my Hype list"}
# {"amr":"add :arg0 playlist :arg1 ( rainstorm :manner sudden )  :arg2 track",
# "sent": "add track to my playlist a sudden rainstorm"}
# {"amr":"please :arg1 ( add :arg1 ( person :arg0-of ( activity :mod-of playlist )  :name ( name :op1 john :op2 deacon )  )  )",
# "sent": "please add John Deacon to the funtime activity playlist"}
# {"amr":"add :arg1 ( track :domain-of puccini :topic this )",
# "sent": "Add track to this is puccini"}
# {"amr":"add :arg1 ( berlin :mod irv )  :arg2 dishwash",
# "sent": "Add irving berlin to my dishwashing"}
# {"amr":"add :arg1 ( go :arg0 ( i :arg0-of be )  :arg4 ( organization :name ( name :op1 st :op2 ives )  )  )",
# "sent": "Add As I Was Going to St Ives to the fantasía"}
# {"amr":"want :arg0 i :arg1 ( lay :arg1 arm :direction down :manner indie )",
# "sent": "I want lay down your arms in the indie español"}
# {"amr":"add :arg1 ( person :name ( name :op1 kevin :op2 cadogan )  )  :arg3 ( list :arg1 80 :arg2 ( hit :arg1 classic )  )",
# "sent": "Add Kevin Cadogan to the 80s Classic Hits list"}
# {"amr":"put :arg1 ( person :name ( name :op1 kim :op2 kibum )  )  :arg2 ( show :arg1 martin )",
# "sent": "Put Kim Kibum in my the martin garrix show"}
# {"amr":"add :arg1 ( up :arg1 ( thing :name ( name :op1 super :op2 turnt )  )  )  :arg1-of possible :arg2 emotron",
# "sent": "Can Super Turnt Up get added to my emotron playlist?"}
# {"amr":"add :arg0 ( 90 :mod-of ( playlist :beneficiary-of ( old :mod-of ( man :arg1-of glad )  )  :mod ultimate )  )  :arg1 name",
# "sent": "Add the name as with gladness men of old to my ultimate 90s playlist"}
# {"amr":"add :arg1 ( song :mod this )  :arg2 game :time ( onto :op1 ( playlist :arg0-of ( hop :arg1 hip )  )  )",
# "sent": "add this song onto hip hop gaming playlist"}
# {"amr":"add :arg1 ( and :op1 ( person :name ( name :op1 hatfield )  )  :op2 north_korea )  :arg2 ( country :name ( name :op1 hot :op2 house )  )",
# "sent": "Add Hatfield and the North to my Hot House"}
# {"amr":"add :arg1 chen :arg2 ( 00 :mod ultimate )",
# "sent": "Add chen jiafeng to Ultimate 00s"}
# {"amr":"add :arg1 ( tune :arg1 france :mod trey )  :arg2 ( thing :name ( name :op1 n' :op2 heavy )  )",
# "sent": "Add the trey gunn tune to my French N' Heavy"}
# {"amr":"add :arg1 ( track :mod this )  :arg2 ( classics :mod morning )",
# "sent": "add this track to morning classical"}
# {"amr":"add :arg1 tune :arg2 ( playlist :mod ( company :mod soft :name ( name :op1 northern :op2 rock )  :wiki northern_rock )  )",
# "sent": "add tune to Soft Rock playlist"}
# {"amr":"add :arg1 ( song :mod this )  :arg2 ( playlist :mod laundry )",
# "sent": "add to laundry playlist with this song"}
# {"amr":"add :arg1 track :arg3 ( playlist :mod ( organization :name ( name :op1 alok :op2 house :op3 party )  )  )",
# "sent": "Add a track to my Alok House Party playlist"}
# {"amr":"place :arg1 ( tune :arg1 workout :mod this )",
# "sent": "Place this tune in workout remix"}
# {"amr":"artist :arg0-of ( add :arg1 ( thing :name ( name :op1 jesper :op2 kyd )  )  :arg1-of like :time ( onto :arg1-of fresh :op1 electronic )  )",
# "sent": "I'd like to add the artist Jesper Kyd onto my fresh electronic"}
# {"amr":"masterwork :op1-of ( before :quant-of ( teenager :arg0-of ( add :arg1 ( artist :mod this :topic ( person :name ( name :name playlist :op1 cleopatra :op2 stratan )  )  )  :arg2 30 )  )  )  :quant 20",
# "sent": "add this artist named Cleopatra Stratan to my playlist named 30 Before 20 Masterworks by Teenagers"}
# {"amr":"add :arg1 ( person :name ( name :op1 erik :op2 santos )  )  :arg2 xplor :location ( playlist :mod-of metal )",
# "sent": "add erik santos in my playlist Metal Xplorer"}
# {"amr":"add :arg1 ( tune :arg1 ( thing :name ( name :op1 favorite :op2 slaughterhouse )  )  )",
# "sent": "Add the tune to Your Favorite Slaughterhouse"}
# {"amr":"add :arg1 ( person :name ( name :op1 joe :op2 gibbs )  )  :arg2 ( organization :mod-of playlist :name ( name :op1 bachelor :op2 party )  )",
# "sent": "add Joe Gibbs to my The Bachelor Party playlist"}
# {"amr":"please :arg1 ( add :arg1 ( thing :name ( name :op1 liberty :op2 forever )  )  :arg2 ( trip :arg1 road )  )",
# "sent": "Please add Liberty Forever to the road trip"}
# {"amr":"add :arg1 ( person :name ( name :op1 chowdhury )  :wiki saber_hossain_chowdhury )  :arg2 ( classic :mod ( soul :quant 35 )  )  :time ( date-entity :time-of ( playlsit :time ( date-entity :year 1970 )  )  :year 1975 )",
# "sent": "add Salil Chowdhury to my 35 Soul Classics 1970 to 1975 playlsit"}
# {"amr":"need :arg0 i :arg1 ( add :arg1 ( post :arg1-of ( start :arg0 ( favorit :source ( silence :arg2 thing )  )  :arg2 all )  )  :arg0 i )",
# "sent": "I need to add to the all things post starting with favorites from the silence"}
# {"amr":"add :arg1 cricket :arg2 ( playlist :mod ( thing :name ( name :op1 mellowed :op2 out :op3 gaming )  )  )",
# "sent": "Add The “Chirping” Crickets to my Mellowed Out Gaming playlist"}
# {"amr":"add :arg1 tune",
# "sent": "Add tune to Blues"}
# {"amr":"want :arg0 ( i :arg0-of ( go :arg1 ( playlist :arg1-of call )  :arg3 genuine )  )  :arg1 album",
# "sent": "I want the Turbonegro album to go on the playlist called Genuine R&B"}
# {"amr":"add :arg0 ( person :name ( name :op1 ali :op2 khan )  )  :arg1 ( thing :name ( name :op1 munawar )  )  :arg2 ( fiesta :mod ( y :mod ( hombr :mod ( y :mod mujer )  )  )  )",
# "sent": "Add Munawar Ali Khan to my mujeres y hombres y fiesta"}
# {"amr":"add :arg1 ( tune :arg1 ( mellow :arg1 ( playlist :arg1-of bar )  )  )",
# "sent": "add tune to my mellow bars playlist"}
# {"amr":"add :arg0 ( playlist :mod thing :mod southern )  :arg1 ( ren :mod mc )  :arg2 it'",
# "sent": "Add mc ren to my It's a Southern Thing playlist"}
# {"amr":"add :arg1 ( song :mod this )  :arg2 ( release :arg1 roadrunn :mod new )",
# "sent": "Add this song to my roadrunner rec new releases"}
# {"amr":"add :arg1 ( song :arg1-of curse :prep-against-of ( organization :mod playlist :name ( name :op1 guest :op2 list :op3 engadget )  )  )",
# "sent": "add Curse song to my playlist Guest List Engadget"}
# {"amr":"need :arg0 i :arg1 ( add :arg1 ( track :arg0-of clean-up :mod another )  :arg0 i )",
# "sent": "I need to add another track to my cleaning"}
# {"amr":"add :arg1 ( artist :mod this )  :arg2 ( party :arg1 80' )",
# "sent": "add this artist to my 80'S PARTY"}
# {"amr":"add :arg1 ( clark :mod gene )  :arg2 ( list :arg1 ( diann' :arg1-of chill )  :arg2 out )",
# "sent": "Add gene clark to diann's chill out list"}
# {"amr":"add :arg1 ( tune :arg1 ( groove :arg1-of rare )  )",
# "sent": "Add a tune to rare groove"}
# {"amr":"iglesia :arg0-of ( add :arg1 ( hopeful :arg2 this )  )",
# "sent": "add hopeful to my this is enrique iglesias"}
# {"amr":"add :arg1 ( putesky :mod scott )  :arg2 ( playlist :mod ( rock :mod indie )  )",
# "sent": "add scott putesky to concentración indie rock playlist"}
# {"amr":"thing :domain ( person :name ( name :op1 shawnna )  )  :name ( name :op1 warm :op2 hearts :op3 feel :op4 good )",
# "sent": "A Shawnna to the Warm Hearts Feel Good"}
# {"amr":"add :arg1 ( person :arg0-of ( play :arg1 ( playlist :mod fast )  )  :mod artist :name ( name :op1 john :op2 william :op3 boone )  )  :arg2 life'",
# "sent": "add artist John William Boone to my life's short; play fast playlist"}
# {"amr":"add :arg1 martin",
# "sent": "add jim martin to Deathcore"}
# {"amr":"put :arg1 ( track :mod this )  :arg2 ( playlist :mod ( bpm :mod soul )  )",
# "sent": "put this track on soul bpm playlist"}
# {"amr":"trevor :mod-of ( mcnevan :arg0-of ( add :arg1 ( artist :mod this )  :arg2 ( track :mod top :mod playlist :poss game )  )  )",
# "sent": "add this artist named trevor mcnevan to the playlist top gaming tracks"}
# {"amr":"add :arg1 ( person :arg0-of ( list :arg1 reggae )  :name ( name :op1 ashley :op2 cafagna :op3 tesoro )  :prep-against-of en )",
# "sent": "Add Ashley Cafagna Tesoro to my reggae en español list"}
# {"amr":"add :arg1 artist :arg2 ( punk :mod ( classic :mod playlist )  )",
# "sent": "Add artist to playlist Classic Punk"}
# {"amr":"add :arg1 ( tune :arg1 ( organization :name ( name :op1 guest :op2 list )  )  )",
# "sent": "Add a tune to my elrow Guest List"}
# {"amr":"want :arg0 i :arg1 ( add :arg1 ( person :arg1-of ( have-rel-role :arg0 ( person :mod-of playlist )  :arg2 friend )  :name ( name :op1 anna :op2 semenovich )  )  :arg2 dinner :arg0 i )",
# "sent": "I want to add Anna Semenovich to the dinner with friends playlist"}
# {"amr":"play :arg1 ( tango :arg1 disco )  :arg2 ( walk :arg1 power )",
# "sent": "Play Disco Tango to Power Walk"}
# {"amr":"add :arg1 ( tune :arg1 music )  :arg2 folk :manner ( thing :name ( name :op1 gaslight :op2 café )  )",
# "sent": "Add tune to my Folk Music At The Gaslight Café"}
# {"amr":"add :arg1 ( artist :mod this )",
# "sent": "add this artist to romántica"}
# {"amr":"please :arg1 ( add :arg1 ( ask :arg0 it :arg1 playlist :arg1-of ( hit :arg0 ( classic :mod 80 )  )  )  )",
# "sent": "Please add 80s Classic Hits Asking for It to playlist"}
# {"amr":"add :arg1 ( artist :mod this )  :arg2 ( barcelona :mod ( sound :mod primavera )  :mod ( date-entity :year 2016 )  )",
# "sent": "add this artist to primavera sound 2016 barcelona"}
# {"amr":"add :arg1 ( album :mod this )  :arg2 ( person :name ( name :op1 trotamundos )  )",
# "sent": "Add this album to Trotamundos"}
# {"amr":"add :arg1 hotel :arg2 ( verano :mod forever )",
# "sent": "Add splendido hotel to my verano forever"}
# {"amr":"add :arg1 lunacy :arg2 ( chill :arg1 playlist )",
# "sent": "add lunacy to my chill out playlist"}
# {"amr":"add :arg1 ( list :arg0 mary :arg2 jane )  :manner ( love :arg1 showstopp )",
# "sent": "Add Without Your Love to my showstopper being mary jane list"}
# {"amr":"add :arg1 ( song :mod this )  :purpose ( list :arg0 ( person :name ( name :op1 trabajo :op2 relax )  )  )",
# "sent": "Add this song to my list Trabajo Relax"}
# {"amr":"add :arg1 ( track :arg0-of ( focus :arg1 zen :mod-of playlist )  :mod this )",
# "sent": "Add this track to my Zen Focus playlist"}
# {"amr":"add :arg1 década :purpose ( list :arg1 ( organization :mod ( thing :name ( name :op1 neo :op2 da )  )  :name ( name :op1 matrix )  )  )",
# "sent": "add décadas to list Neo da Matrix"}
# {"amr":"need :arg0 ( playlist :mod ( thing :name ( name :op1 zen :op2 focus )  )  )  :arg1 ( person :name ( name :op1 david :op2 franj )  )",
# "sent": "The Zen Focus playlist needs David Franj in"}
# {"amr":"put :arg1 4 :arg2 blue :time ( onto :op1 ( 00 :mod ultimate )  )",
# "sent": "put four in blue onto Ultimate 00s"}
# {"amr":"add :arg0 ( bergman :mod marit )  :arg1 50 :op1-of ( top :arg1-of ( want :arg0 i )  :mod globe )",
# "sent": "I want global top 50 to have marit bergman added to"}
# {"amr":"add :arg1 ( fly :arg1 woman :manner ( company :mod-of playlist :name ( name :op1 northern :op2 rock )  :wiki northern_rock )  )",
# "sent": "add flying to my Women of Rock playlist"}
# {"amr":"add :arg0 ( person :name ( name :op1 gary :op2 valenciano )  )  :arg1 ( game :mod power )",
# "sent": "Add Gary Valenciano to the power gaming"}
# {"amr":"add :arg0 ( thing :name ( name :op1 urban :op2 poet )  )  :arg1 track",
# "sent": "Add track to Urban Poet"}
# {"amr":"title :arg0 ( country :mod-of ( favorit :arg1-of ( add :arg0 ( style :mod nelson )  )  )  )  :arg1 playlist :arg2 ( thing :name ( name :op1 spinnin' :op2 records :op3 top :op4 100 )  )",
# "sent": "add country favorites willie nelson style to my playlist titled Spinnin' Records Top 100"}
# '  \n[{"amr": "describe :arg0 ( person :name ( name :op1 ryan )  )  :arg1 person :arg2 genius",\n"sent": "ryan \'s description of himself : a genius .",\n"id": "demo"}]\n'
